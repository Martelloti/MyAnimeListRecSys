# %% [markdown]
# # Projeto Udacity - Sistema de recomendações para usuários do MyAnimeList

# %%
from collections import defaultdict
import pandas as pd
import numpy as np
import scipy
from sklearn.model_selection import train_test_split
from scipy.sparse.linalg import svds
import matplotlib.pyplot as plt
import surprise as sp

# %% [markdown]
# Referências e explicações:
#
# [Datasets utilizados](https://www.kaggle.com/azathoth42/myanimelist/version/9#_=_)
#
# [Bíblia](https://www.kaggle.com/gspmoreira/recommender-systems-in-python-101)
#
# [Merges explicados](https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/)
#
# [Gráficos explicados](http://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot)
#
# [Análises de rating](https://towardsdatascience.com/building-and-testing-recommender-systems-with-surprise-step-by-step-d4ba702ef80b)

# %% [markdown]
# # Datasets
#
# The datasets are mainly divided in three. One with info about the MyAnimeList customers (UsersDF) such as location, gender, birth date and so on. Another one for info about the anime, which brings data like the title of the show, what genre is it inside and even the opening themes. The last one (and also the biggest one) is all the scores that a certain user had with a show.

# %%
UsersDF = pd.read_csv('users_cleaned.csv')
AnimesDF = pd.read_csv('anime_cleaned.csv')
ScoresDF = pd.read_csv('animelists_cleaned.csv')

# %%
AnimesDF.head()
# Out:
#    anime_id                title              title_english title_japanese  \
# 0     11013        Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 1      2104     Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 2      5262   Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 3       721        Princess Tutu              Princess Tutu      プリンセスチュチュ
# 4     12365  Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                   title_synonyms  \
# 0                                Youko x Boku SS
# 1                           The Inland Sea Bride
# 2  Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                            NaN
# 4                               Bakuman Season 3
#
#                                            image_url type    source  episodes  \
# 0  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        12
# 1  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        26
# 2  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        51
# 3  https://myanimelist.cdn-dena.com/images/anime/...   TV  Original        38
# 4  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        25
#
#             status       ...                  broadcast  \
# 0  Finished Airing       ...         Fridays at Unknown
# 1  Finished Airing       ...                    Unknown
# 2  Finished Airing       ...                    Unknown
# 3  Finished Airing       ...         Fridays at Unknown
# 4  Finished Airing       ...                    Unknown
#
#                                              related  \
# 0  {'Adaptation': [{'mal_id': 17207, 'type': 'man...
# 1  {'Adaptation': [{'mal_id': 759, 'type': 'manga...
# 2  {'Adaptation': [{'mal_id': 101, 'type': 'manga...
# 3  {'Adaptation': [{'mal_id': 1581, 'type': 'mang...
# 4  {'Adaptation': [{'mal_id': 9711, 'type': 'mang...
#
#                                             producer          licensor  \
# 0  Aniplex, Square Enix, Mainichi Broadcasting Sy...  Sentai Filmworks
# 1                  TV Tokyo, AIC, Square Enix, Sotsu        Funimation
# 2                                    TV Tokyo, Sotsu               NaN
# 3                 Memory-Tech, GANSIS, Marvelous AQL         ADV Films
# 4                                      NHK, Shueisha               NaN
#
#              studio                                     genre  \
# 0  David Production    Comedy, Supernatural, Romance, Shounen
# 1             Gonzo  Comedy, Parody, Romance, School, Shounen
# 2         Satelight             Comedy, Magic, School, Shoujo
# 3    Hal Film Maker    Comedy, Drama, Magic, Romance, Fantasy
# 4         J.C.Staff           Comedy, Drama, Romance, Shounen
#
#                                        opening_theme  \
# 0                              ['"Nirvana" by MUCC']
# 1                 ['"Romantic summer" by SUN&LUNAR']
# 2  ['#1: "Minna no Tamago (みんなのたまご)" by Shugo Cha...
# 3             ['"Morning Grace" by Ritsuko Okazaki']
# 4  ['#1: "Moshimo no Hanashi (もしもの話)" by nano.RIP...
#
#                                         ending_theme  duration_min  \
# 0  ['#1: "Nirvana" by MUCC (eps 1, 11-12)', '#2: ...          24.0
# 1  ['#1: "Ashita e no Hikari (明日への光)" by Asuka Hi...          24.0
# 2  ['#1: "Rottara Rottara (ロッタラ ロッタラ)" by Buono! ...          24.0
# 3  ['"Watashi No Ai Wa Chiisaikeredo" by Ritsuko ...          16.0
# 4  ['#1: "Pride on Everyday" by Sphere (eps 1-13)...          24.0
#
#    aired_from_year
# 0           2012.0
# 1           2007.0
# 2           2008.0
# 3           2002.0
# 4           2012.0
#
# [5 rows x 33 columns]

# %%
UsersDF.head()
# Out:
#          username  user_id  user_watching  user_completed  user_onhold  \
# 0        karthiga  2255153              3              49            1
# 1       Damonashu    37326             45             195           27
# 2           bskai   228342             25             414            2
# 3  terune_uzumaki   327311              5               5            0
# 4           Bas_G  5015094             35             114            6
#
#    user_dropped  user_plantowatch  user_days_spent_watching  gender  \
# 0             0                 0                 55.091667  Female
# 1            25                59                 82.574306    Male
# 2             5                11                159.483333    Male
# 3             0                 0                 11.394444  Female
# 4            20               175                 30.458333    Male
#
#               location           birth_date  access_rank            join_date  \
# 0      Chennai, India   1990-04-29 00:00:00          NaN  2013-03-03 00:00:00
# 1     Detroit,Michigan  1991-08-01 00:00:00          NaN  2008-02-13 00:00:00
# 2      Nayarit, Mexico  1990-12-14 00:00:00          NaN  2009-08-31 00:00:00
# 3    Malaysia, Kuantan  1998-08-24 00:00:00          NaN  2010-05-10 00:00:00
# 4  Nijmegen, Nederland  1999-10-24 00:00:00          NaN  2015-11-26 00:00:00
#
#            last_online  stats_mean_score  stats_rewatched  stats_episodes
# 0  2014-02-04 01:32:00              7.43              0.0            3391
# 1  2017-07-10 06:52:54              6.15              6.0            4903
# 2  2014-05-12 16:35:00              8.27              1.0            9701
# 3  2012-10-18 19:06:00              9.70              6.0             697
# 4  2018-05-10 20:53:37              7.86              0.0            1847

# %%
ScoresDF.head()
# Out:
#    username  anime_id  my_watched_episodes my_start_date my_finish_date  \
# 0  karthiga        21                  586    0000-00-00     0000-00-00
# 1  karthiga        59                   26    0000-00-00     0000-00-00
# 2  karthiga        74                   26    0000-00-00     0000-00-00
# 3  karthiga       120                   26    0000-00-00     0000-00-00
# 4  karthiga       178                   26    0000-00-00     0000-00-00
#
#    my_score  my_status  my_rewatching  my_rewatching_ep      my_last_updated  \
# 0         9          1            NaN                 0  2013-03-03 10:52:53
# 1         7          2            NaN                 0  2013-03-10 13:54:51
# 2         7          2            NaN                 0  2013-04-27 16:43:35
# 3         7          2            NaN                 0  2013-03-03 10:53:57
# 4         7          2            0.0                 0  2013-03-27 15:59:13
#
#   my_tags
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#Since InteractionsDF is a huge DF (2GB of data) I`ll only take the columns that are important for the recommendation system
ScoresDF = ScoresDF[['username', 'anime_id', 'my_score', 'my_status']]

# %%
#ScoresDFSampled = ScoresDF.sample(frac = 0.99, random_state = 42)
#ScoresDFSampled.head()

# %%
#Analysing all the possible values for the score
lower_rating = ScoresDF['my_score'].min()
upper_rating = ScoresDF['my_score'].max()
print('Range of ratings vary between: {0} to {1}'.format(lower_rating, upper_rating))
# Out:
# Range of ratings vary between: 0 to 10

# %%
#Only filtering animes in which people actually watched, are watching or are on hold as they are the most revelant for the rec sys
#RelevantScoresDF = ScoresDF[(ScoresDF['my_status'] == 1) | (ScoresDF['my_status'] == 2) | (ScoresDF['my_status'] == 3)]

# %%
#Counting how many relevant scores each user have done, resetting the index (so the series could become a DF again) and changing the column names
RatedsPerUser = ScoresDF['username'].value_counts().reset_index().rename(columns={"username": "animes_rated", "index": "username"})

# %%
RatedsPerUser = RatedsPerUser.sample(frac = 0.05, random_state = 42)

# %%
#Grouping users whom had the same amount of animes rated
UserRatedsAggregated = RatedsPerUser['animes_rated'].value_counts().reset_index().rename(columns={"animes_rated": "group_size", "index": "animes_rated"}).sort_values(by=['animes_rated'])
UserRatedsAggregated.head(n = 30)
# Out:
#     animes_rated  group_size
# 56             1          16
# 62             2          16
# 16             3          20
# 2              4          23
# 3              5          23
# 7              6          22
# 14             7          20
# 0              8          24
# 63             9          16
# 72            10          15
# 37            11          17
# 30            12          18
# 19            13          19
# 73            14          15
# 9             15          21
# 40            16          17
# 22            17          19
# 29            18          18
# 84            19          14
# 36            20          17
# 5             21          22
# 8             22          21
# 88            23          14
# 81            24          14
# 78            25          15
# 26            26          18
# 65            27          15
# 18            28          19
# 52            29          16
# 24            30          19

# %%
#Counting how many relevant scores each anime has, resetting the index (so the series could become a DF again) and changing the column names
RatedsPerAnime = ScoresDF['anime_id'].value_counts().reset_index().rename(columns={"anime_id": "number_of_users", "index": "anime_id"})
RatedsPerAnime.head()
# Out:
#    anime_id  number_of_users
# 0      1535            81332
# 1      1575            67721
# 2       226            64486
# 3      5114            63649
# 4      4224            63278

# %%
#Grouping users whom had the same amount of animes rated
AnimeRatedsAggregated = RatedsPerAnime['number_of_users'].value_counts().reset_index().rename(columns={"number_of_users": "group_size", "index": "number_of_users"}).sort_values(by=['number_of_users'])
AnimeRatedsAggregated.head(n = 30)
# Out:
#      number_of_users  group_size
# 443                1           3
# 24                 2          11
# 26                 3          11
# 21                 4          12
# 6                  5          16
# 17                 6          13
# 10                 7          14
# 8                  8          16
# 1                  9          22
# 2                 10          21
# 9                 11          15
# 4                 12          19
# 15                13          13
# 0                 14          22
# 18                15          13
# 5                 16          18
# 23                17          12
# 7                 18          16
# 3                 19          21
# 20                20          12
# 11                21          14
# 16                22          13
# 39                23           8
# 12                24          14
# 44                25           8
# 27                26          11
# 38                27           8
# 13                28          14
# 35                29           9
# 22                30          12

# %%
#As expected, most of our users have rated a lower amount of animes, but even so 
#I think we don't lose much information by excluding these customers for the user cold-start issue, so we will
#create an abirtrary cut line of only analysing users that have interacted with at least 10 animes

plt.suptitle("Distribution of users", fontsize=13, fontweight=0, color='black', style='italic', y=1.02)
plt.plot('animes_rated', 'group_size', data = UserRatedsAggregated, color = 'blue')
plt.xlabel('Number of animes rated')
plt.ylabel('Number of people in that group')
plt.xlim(left = 0, right = 500)
plt.show()

# %%
plt.suptitle("Distribution of animes", fontsize=13, fontweight=0, color='black', style='italic', y=1.02)
plt.plot('number_of_users', 'group_size', data = AnimeRatedsAggregated, color = 'olive')
plt.xlabel('Number of times the anime was rated')
plt.ylabel('Number of animes in that group')
plt.xlim(left = 0, right = 500)
plt.show()

# %%
#Here we create another dataframe which contain only customers that have at least 10 valueable (as we filtered
#back then) ratings by merging our initial frame and the RatedsPerUser one. We also just bring the first three columns
#because it is already in the format of the library we will use

UserRatedsCutten = RatedsPerUser[RatedsPerUser['animes_rated'] >= 800]
AnimeRatedsCutten = RatedsPerAnime[RatedsPerAnime['number_of_users'] >= 50]
ScoresDFHotStart = pd.merge(ScoresDF, UserRatedsCutten, left_on = 'username', right_on = 'username', how = 'inner')
ScoresDFHotStart = pd.merge(ScoresDFHotStart, AnimeRatedsCutten, left_on = 'anime_id', right_on = 'anime_id', how = 'inner')

# %%
#Just for the record, lets analyse the pattern for the scores given by the site users

ScoresDF.count()
# Out:
# username     31283787
# anime_id     31284030
# my_score     31284030
# my_status    31284030
# dtype: int64

# %%
ScoresDFHotStart.count()
# Out:
# username           399165
# anime_id           399165
# my_score           399165
# my_status          399165
# animes_rated       399165
# number_of_users    399165
# dtype: int64

# %%
#ScoresDFHotStart.to_csv("Scores.csv")

# %%
#ScoresDFHotStart1 = ScoresDFHotStart[0:50000]

# %%
from surprise.model_selection import train_test_split

reader = sp.Reader(rating_scale=(0, 10))
data = sp.Dataset.load_from_df(ScoresDFHotStart[['username', 'anime_id', 'my_score']], reader)
#trainset = data.build_full_trainset()
algo = sp.SVD()
#algo.fit(trainset)
trainset, testset = train_test_split(data, test_size=.25)
#testset = trainset.build_anti_testset()
algo.fit(trainset)
predictions = algo.test(testset)

def get_Iu(uid):
    """ return the number of items rated by given user
    args: 
      uid: the id of the user
    returns: 
      the number of items rated by the user
    """
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError: # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """ return number of users that have rated given item
    args:
      iid: the raw id of the item
    returns:
      the number of users that have rated the item.
    """
    try: 
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:
        return 0
    
last_predictions = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])
last_predictions['Iu'] = last_predictions.uid.apply(get_Iu)
last_predictions['Ui'] = last_predictions.iid.apply(get_Ui)
last_predictions['err'] = abs(last_predictions.est - last_predictions.rui)
sp.accuracy.rmse(predictions)
# Out:
# RMSE: 3.1490
# 3.1490157815318223

# %%
last_predictions = last_predictions.sort_values(by=['uid', 'err'])

# %%
#rui ("Nota verdadeira") - Como o test_set é gerado artificialmente, a nota verdadeira nesse caso é a média global
# de todos os ratings do trainset.

#last_predictions[last_predictions['iid'] == 32696]
last_predictions.head(n = 20000)
# Out:
#                uid    iid   rui        est                    details   Iu  \
# 38687        -Kazu   1889  10.0  10.000000  {'was_impossible': False}  783
# 45567        -Kazu   2251  10.0  10.000000  {'was_impossible': False}  783
# 54139        -Kazu  27821  10.0  10.000000  {'was_impossible': False}  783
# 67473        -Kazu   6922  10.0  10.000000  {'was_impossible': False}  783
# 42023        -Kazu  18153   8.0   7.988786  {'was_impossible': False}  783
# 29004        -Kazu   4903   7.0   6.979018  {'was_impossible': False}  783
# 66471        -Kazu     73   9.0   8.967650  {'was_impossible': False}  783
# 11986        -Kazu   6896   8.0   7.939928  {'was_impossible': False}  783
# 35019        -Kazu   1709   8.0   8.065096  {'was_impossible': False}  783
# 35417        -Kazu    134   8.0   8.073327  {'was_impossible': False}  783
# 27202        -Kazu   1944   8.0   7.911230  {'was_impossible': False}  783
# 78681        -Kazu   2966   9.0   9.121781  {'was_impossible': False}  783
# 94197        -Kazu   8514   8.0   8.128499  {'was_impossible': False}  783
# 28966        -Kazu  20473   8.0   8.156260  {'was_impossible': False}  783
# 13821        -Kazu  23945   8.0   7.840137  {'was_impossible': False}  783
# 66511        -Kazu  20541   8.0   8.164490  {'was_impossible': False}  783
# 82416        -Kazu    229   8.0   7.831705  {'was_impossible': False}  783
# 25450        -Kazu    275   8.0   8.172577  {'was_impossible': False}  783
# 157          -Kazu   5080   8.0   8.220572  {'was_impossible': False}  783
# 72299        -Kazu  13663   8.0   7.779042  {'was_impossible': False}  783
# 11877        -Kazu  18497   8.0   8.304112  {'was_impossible': False}  783
# 46029        -Kazu   1195   9.0   8.687239  {'was_impossible': False}  783
# 94735        -Kazu    487   9.0   8.675960  {'was_impossible': False}  783
# 14972        -Kazu    570   5.0   4.641575  {'was_impossible': False}  783
# 44893        -Kazu  10417   8.0   7.636826  {'was_impossible': False}  783
# 95362        -Kazu   1367   9.0   8.610184  {'was_impossible': False}  783
# 8340         -Kazu   7549   8.0   7.609990  {'was_impossible': False}  783
# 17815        -Kazu  10196   9.0   8.606782  {'was_impossible': False}  783
# 19152        -Kazu  22199   8.0   8.411290  {'was_impossible': False}  783
# 98236        -Kazu  11499   7.0   6.588444  {'was_impossible': False}  783
# ...            ...    ...   ...        ...                        ...  ...
# 92308  FlareLamont   8630   7.0   9.281542  {'was_impossible': False}  858
# 25148  FlareLamont   1195  10.0   7.711115  {'was_impossible': False}  858
# 12698  FlareLamont  33475   6.0   3.709658  {'was_impossible': False}  858
# 9594   FlareLamont   1619  10.0   7.658723  {'was_impossible': False}  858
# 74601  FlareLamont   7017   0.0   2.357762  {'was_impossible': False}  858
# 23269  FlareLamont    449   8.0   5.620219  {'was_impossible': False}  858
# 38472  FlareLamont     66  10.0   7.604021  {'was_impossible': False}  858
# 71804  FlareLamont  16934   0.0   2.412935  {'was_impossible': False}  858
# 31481  FlareLamont  14511   0.0   2.441997  {'was_impossible': False}  858
# 99595  FlareLamont   9750   0.0   2.483797  {'was_impossible': False}  858
# 87402  FlareLamont   9907   0.0   2.484053  {'was_impossible': False}  858
# 95585  FlareLamont  22145   0.0   2.502982  {'was_impossible': False}  858
# 87795  FlareLamont   7768   0.0   2.561666  {'was_impossible': False}  858
# 40794  FlareLamont  21235   0.0   2.564833  {'was_impossible': False}  858
# 53613  FlareLamont  18277   0.0   2.602472  {'was_impossible': False}  858
# 8709   FlareLamont   5680   9.0   6.377365  {'was_impossible': False}  858
# 58672  FlareLamont  31439   0.0   2.641970  {'was_impossible': False}  858
# 91177  FlareLamont  23281   0.0   2.655980  {'was_impossible': False}  858
# 62742  FlareLamont  10213   9.0   6.321948  {'was_impossible': False}  858
# 30855  FlareLamont  22071   0.0   2.704974  {'was_impossible': False}  858
# 4448   FlareLamont   5781   9.0   6.292932  {'was_impossible': False}  858
# 41592  FlareLamont  21353   0.0   2.753097  {'was_impossible': False}  858
# 5857   FlareLamont  14653   0.0   2.760176  {'was_impossible': False}  858
# 7623   FlareLamont  10638   8.0   5.239271  {'was_impossible': False}  858
# 41133  FlareLamont  36722   0.0   2.859983  {'was_impossible': False}  858
# 60905  FlareLamont  17831   0.0   2.866086  {'was_impossible': False}  858
# 81002  FlareLamont   4192   0.0   2.870633  {'was_impossible': False}  858
# 18064  FlareLamont  17909   0.0   2.879668  {'was_impossible': False}  858
# 65292  FlareLamont  16035   0.0   2.956068  {'was_impossible': False}  858
# 59822  FlareLamont  15687   0.0   2.974374  {'was_impossible': False}  858
#
#         Ui       err
# 38687  170  0.000000
# 45567  190  0.000000
# 54139  139  0.000000
# 67473  156  0.000000
# 42023  221  0.011214
# 29004   81  0.020982
# 66471  153  0.032350
# 11986   60  0.060072
# 35019   68  0.065096
# 35417  149  0.073327
# 27202   25  0.088770
# 78681  203  0.121781
# 94197   86  0.128499
# 28966   49  0.156260
# 13821  106  0.159863
# 66511  146  0.164490
# 82416   66  0.168295
# 25450   46  0.172577
# 157     36  0.220572
# 72299  127  0.220958
# 11877  103  0.304112
# 46029  213  0.312761
# 94735   80  0.324040
# 14972  104  0.358425
# 44893   68  0.363174
# 95362   39  0.389816
# 8340    20  0.390010
# 17815   70  0.393218
# 19152  185  0.411290
# 98236  200  0.411556
# ...    ...       ...
# 92308  166  2.281542
# 25148  213  2.288885
# 12698  106  2.290342
# 9594    40  2.341277
# 74601   71  2.357762
# 23269   70  2.379781
# 38472  152  2.395979
# 71804  118  2.412935
# 31481   84  2.441997
# 99595  134  2.483797
# 87402   47  2.484053
# 95585   83  2.502982
# 87795   69  2.561666
# 40794   21  2.564833
# 53613  186  2.602472
# 8709   210  2.622635
# 58672   64  2.641970
# 91177  148  2.655980
# 62742  139  2.678052
# 30855   71  2.704974
# 4448   117  2.707068
# 41592  136  2.753097
# 5857    82  2.760176
# 7623    89  2.760729
# 41133    2  2.859983
# 60905  132  2.866086
# 81002  105  2.870633
# 18064  135  2.879668
# 65292  104  2.956068
# 59822  107  2.974374
#
# [20000 rows x 8 columns]

# %%
AnimesDF[AnimesDF['anime_id'] == 296]
# Out:
#       anime_id         title title_english title_japanese title_synonyms  \
# 4799       296  Dragon Drive  Dragon Drive       ドラゴンドライブ            NaN
#
#                                               image_url type source  episodes  \
# 4799  https://myanimelist.cdn-dena.com/images/anime/...   TV  Manga        38
#
#                status       ...                        broadcast  \
# 4799  Finished Airing       ...         Thursdays at 18:00 (JST)
#
#                                                 related  \
# 4799  {'Adaptation': [{'mal_id': 935, 'type': 'manga...
#
#                                              producer              licensor  \
# 4799  Bandai Visual, Nihon Ad Systems, TV Tokyo Music  Bandai Entertainment
#
#         studio                                              genre  \
# 4799  Madhouse  Action, Sci-Fi, Adventure, Comedy, Fantasy, Sc...
#
#                        opening_theme  \
# 4799  ['"True" by Shimokawa Mikuni']
#
#                                      ending_theme  duration_min  \
# 4799  ['"tatta, hitotsu no" by Shimokawa Mikuni']          25.0
#
#       aired_from_year
# 4799           2002.0
#
# [1 rows x 33 columns]

# %%
ScoresDF[(ScoresDF['username'] == '-Kazu') & (ScoresDF['anime_id'] == 8041)]
# Out:
# Empty DataFrame
# Columns: [username, anime_id, my_score, my_status]
# Index: []
